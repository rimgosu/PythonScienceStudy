# %%
# 이미지 경로를 실제 파일로 저장
from urllib.request import urlretrieve
import os
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

# %%
img_dir = r'C:\Users\newny\Desktop\PythonCrawling\pythonsciencestudy\img'
if not os.path.isdir(img_dir):
    os.mkdir(img_dir)

# %%
driver = wb.Chrome()
driver.get('https://search.naver.com/search.naver?sm=tab_hty.top&where=image&query=%EB%8F%85%EC%88%98%EB%A6%AC&oquery=%ED%8C%90%EB%8B%A4&tqi=iffhndprvmZssK0FdH4ssssstFl-307532')

# %%
for _ in range(10):
    body = driver.find_element(By.TAG_NAME, 'body')
    body.send_keys(Keys.END)
    time.sleep(2)

# %%
imgs = driver.find_elements(By.CSS_SELECTOR, "#main_pack > section.sc_new.sp_nimage._prs_img._imageSearchPC > div > div.photo_group._listGrid > div.photo_tile._grid > div > div > div.thumb > a > img")

# 'src'속성 가지고 와
# 단일 요소.get_attribute
imgs[0].get_attribute('src')
# Out:
# 'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzAzMTZfMTA5%2FMDAxNjc4OTY1MDU1NDEz.mpj-dKqVv49Wcn3wsNMzUFrvhXfmvm7CEJCgmjGEIJEg.3xV8neZVrjAW3tueNENPagxgpNZejWWXrfoGFXISoA8g.JPEG.xianu%2Ftumblr_22403ad7014670208e077a0fc5b65389_36eb092c_500.jpg&type=a340'

# %%
# src만 담아줄 리스트를 제작
src = []
for i in range(len(imgs)):
    src.append(imgs[i].get_attribute('src'))
src
# Out:
# ['https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzAzMTZfMTA5%2FMDAxNjc4OTY1MDU1NDEz.mpj-dKqVv49Wcn3wsNMzUFrvhXfmvm7CEJCgmjGEIJEg.3xV8neZVrjAW3tueNENPagxgpNZejWWXrfoGFXISoA8g.JPEG.xianu%2Ftumblr_22403ad7014670208e077a0fc5b65389_36eb092c_500.jpg&type=a340',
#  'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzA2MjBfMTI4%2FMDAxNjg3MjQ4NjE0NjQ0.lyVBO3dpcpAjHT8CArUaLtAF2XI2Hwp90Xycraw4D0Ug.nw-vWnT3IBcRsyq7jhMz5fou58JIYa5mZ5T_3F2sGO8g.JPEG.ahnshine%2FEagle_Plumage.jpg&type=a340',
#  'https://search.pstatic.net/common/?src=http%3A%2F%2Fblogfiles.naver.net%2FMjAyMzAyMjhfMTQw%2FMDAxNjc3NTU2MTQ3MTk3.cQSYua8QLAwM0b_TMIJ-sBQzQl4osT6Iu6IYnvl_wZEg.vdSQdwWMNKXwdr2dJBzazdTbweG0H60uUzxT4tW3Ty8g.JPEG.jg8600%2F01-1.jpg&type=l340_165',
# ...

# %%
# 이미지의 경로를 실제 파일로 저장
for i in range(len(src)):
    urlretrieve(src[i], img_dir + str(i) + '.png')

# %% [markdown]
# ## 한셀로 합치기

# %%
# 이미지 경로를 실제 파일로 저장
from urllib.request import urlretrieve
import os
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time

def run_crawl_img(
    경로,
    url,
    img_css
):
    img_dir = 경로
    if not os.path.isdir(img_dir):
        os.mkdir(img_dir)

    driver = wb.Chrome()
    driver.get(url)

    for _ in range(10):
        body = driver.find_element(By.TAG_NAME, 'body')
        body.send_keys(Keys.END)
        time.sleep(2)

    imgs = driver.find_elements(By.CSS_SELECTOR, img_css)

    # src만 담아줄 리스트를 제작
    src = []
    for i in range(len(imgs)):
        src.append(imgs[i].get_attribute('src'))


    # 이미지의 경로를 실제 파일로 저장
    for i in range(len(src)):
        urlretrieve(src[i], img_dir + '\img' + str(i) + '.png')

# %%
run_crawl_img(
    경로 = r'C:\Users\newny\Desktop\PythonCrawling\pythonsciencestudy\img',
    url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=image&query=%EB%8F%85%EC%88%98%EB%A6%AC&oquery=%ED%8C%90%EB%8B%A4&tqi=iffhndprvmZssK0FdH4ssssstFl-307532',
    img_css = "#main_pack > section.sc_new.sp_nimage._prs_img._imageSearchPC > div > div.photo_group._listGrid > div.photo_tile._grid > div > div > div.thumb > a > img"
)
